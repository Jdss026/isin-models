# %%
import matplotlib.pyplot as plt
import torch.sparse as sp
from scipy.sparse import lil_matrix
import torch
from paramets import *
import numpy as np
from tqdm import tqdm

# %% [markdown]
# ## Configurations

# %% [markdown]
# ## Rewrite the original code using torch

# %%
# Ng, Tf = 64, 10001

def laplacian(n):
    # Total number of grid points
    total_points = n * n
    matrix_laplacian = lil_matrix((total_points, total_points))
    
    # Fill the matrix based on finite difference method for Laplacian
    for i in range(n):
        for j in range(n):
            row = i * n + j  # Current grid point
            # Diagonal element
            matrix_laplacian[row, row] = 4
            # Check and update neighbors (left, right, up, down)
            if i > 0:
                matrix_laplacian[row, (i - 1) * n + j] = -1  # Up
            if i < n - 1:
                matrix_laplacian[row, (i + 1) * n + j] = -1  # Down
            if j > 0:
                matrix_laplacian[row, i * n + (j - 1)] = -1  # Left
            if j < n - 1:
                matrix_laplacian[row, i * n + (j + 1)] = -1  # Right
    
    # Convert to CSR format for efficient arithmetic operations
    
    matrix_laplacian = matrix_laplacian.tocsr()
    matrix_laplacian = -matrix_laplacian

    # Extract coordinates and values
    row_indices = []
    col_indices = []
    values = []

    for row in range(matrix_laplacian.shape[0]):
        start = matrix_laplacian.indptr[row]
        end = matrix_laplacian.indptr[row + 1]
        row_indices.extend([row] * (end - start))
        col_indices.extend(matrix_laplacian.indices[start:end])
        values.extend(matrix_laplacian.data[start:end])
    
    # convert to coo_matrix
    coo_matrix = torch.sparse_coo_tensor(
                torch.tensor([row_indices, col_indices], dtype=torch.int64),
                torch.tensor(values, dtype=torch.float32),
                torch.Size((n*n,n*n))
                )
    return coo_matrix

master_list = []
def integrate(L, u, T):
    '''  simulates the equation and plots it at different instants '''
    T = torch.tensor([T], device='cpu')
    for i in range(Tf.item()):
        noise = torch.normal(mean=0.0, std=1.0, size=(Ng * Ng, 1), device='cpu')
        u = u - dt * (a * u + b * u * u * u - c - k * torch.mm(L, u)) + torch.sqrt(2 * T * dt) * noise  # Euler's method
        if (i==10000):
            master_list.append(u)

# %% [markdown]
# ## Calculate the mean of configurations

# %%
def avg_realizations(master_list, Ng):
    """ Evaluate the average over the configurations (realizations)"""
    mean_config = []
    size = len(master_list)
    N = Ng*Ng
    temp = 0
    for point in tqdm(range(N), desc="Processing", ncols=100, ascii=True):
        for config in range(size):
            temp += master_list[config][point]
        mean_config.append(temp/size)
        temp = 0
    mean_config = torch.tensor(mean_config)
    mean_config = mean_config.view((Ng, Ng))
    plt.figure(figsize=(4, 3))
    plt.imshow(mean_config)
    plt.show()
    return mean_config

# mean_config = avg_realizations(master_list, Ng)
# plt.imshow(mean_config)
# plt.show()

# %%
def avg_final(mean_config, Ng):
    sum = 0 
    for x in range(Ng):
        for y in range(Ng):
            sum = sum + mean_config[x][y]
    return sum / (Ng*Ng)

# media_final(mean_config, Ng)

# %% [markdown]
# ## RUN PIPELINE

# %%
# generate the grid and initialise the field

## define o dispositivo cuda a ser utilizado

device = torch.device('cpu')

x = torch.linspace(-1, 1, Ng)
y = torch.linspace(-1, 1, Ng)
X, Y = torch.meshgrid(x, y)

## simula 100 configurações finais com os parametros iniciais
L = laplacian(Ng)
L = L.to(device)         # construct the laplacian
N_real = 50

list_vev = []
list_temperature = [0.01, 5]
for T in list_temperature:
  print(f"---------------- Temperature: {T} --------------------- ")
  for realization in tqdm(range(N_real), desc="Processing", ncols=100, ascii=True):
    u = torch.randn(Ng * Ng, 1, device=device)  # Initial data
    integrate(L, u, T)    # simulate
    # if realization % 10 ==0:
      # print(f'Realization: {realization}')

  mean_config = avg_realizations(master_list, Ng)
  VEV = avg_final(mean_config, Ng)
  list_vev.append(VEV)
# Out:
# d:\Anaconda\Anaconda\Lib\site-packages\torch\functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\TensorShape.cpp:3484.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ---------------- Temperature: 0.01 ---------------------
# Processing: 100%|###################################################| 50/50 [06:30<00:00,  7.80s/it]
# Processing: 100%|#############################################| 4096/4096 [00:01<00:00, 2467.42it/s]
# ---------------- Temperature: 5 ---------------------
# Processing:  72%|####################################7              | 36/50 [04:45<01:50,  7.92s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\jdss0\Documents\workspace\ising-models\notebooks\jonas\2d_langevin_v4.ipynb Cell 9 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/jdss0/Documents/workspace/ising-models/notebooks/jonas/2d_langevin_v4.ipynb#X11sZmlsZQ%3D%3D?line=19'>20</a> for realization in tqdm(range(N_real), desc="Processing", ncols=100, ascii=True):
#      <a href='vscode-notebook-cell:/c%3A/Users/jdss0/Documents/workspace/ising-models/notebooks/jonas/2d_langevin_v4.ipynb#X11sZmlsZQ%3D%3D?line=20'>21</a>   u = torch.randn(Ng * Ng, 1, device=device)  # Initial data
# ---> <a href='vscode-notebook-cell:/c%3A/Users/jdss0/Documents/workspace/ising-models/notebooks/jonas/2d_langevin_v4.ipynb#X11sZmlsZQ%3D%3D?line=21'>22</a>   integrate(L, u, T)    # simulate
#      <a href='vscode-notebook-cell:/c%3A/Users/jdss0/Documents/workspace/ising-models/notebooks/jonas/2d_langevin_v4.ipynb#X11sZmlsZQ%3D%3D?line=22'>23</a>   # if realization % 10 ==0:
#      <a href='vscode-notebook-cell:/c%3A/Users/jdss0/Documents/workspace/ising-models/notebooks/jonas/2d_langevin_v4.ipynb#X11sZmlsZQ%3D%3D?line=23'>24</a>     # print(f'Realization: {realization}')
#      <a href='vscode-notebook-cell:/c%3A/Users/jdss0/Documents/workspace/ising-models/notebooks/jonas/2d_langevin_v4.ipynb#X11sZmlsZQ%3D%3D?line=25'>26</a> mean_config = avg_realizations(master_list, Ng)
#
# c:\Users\jdss0\Documents\workspace\ising-models\notebooks\jonas\2d_langevin_v4.ipynb Cell 9 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/jdss0/Documents/workspace/ising-models/notebooks/jonas/2d_langevin_v4.ipynb#X11sZmlsZQ%3D%3D?line=52'>53</a> for i in range(Tf.item()):
#      <a href='vscode-notebook-cell:/c%3A/Users/jdss0/Documents/workspace/ising-models/notebooks/jonas/2d_langevin_v4.ipynb#X11sZmlsZQ%3D%3D?line=53'>54</a>     noise = torch.normal(mean=0.0, std=1.0, size=(Ng * Ng, 1), device='cpu')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/jdss0/Documents/workspace/ising-models/notebooks/jonas/2d_langevin_v4.ipynb#X11sZmlsZQ%3D%3D?line=54'>55</a>     u = u - dt * (a * u + b * u * u * u - c - k * torch.mm(L, u)) + torch.sqrt(2 * T * dt) * noise  # Euler's method
#      <a href='vscode-notebook-cell:/c%3A/Users/jdss0/Documents/workspace/ising-models/notebooks/jonas/2d_langevin_v4.ipynb#X11sZmlsZQ%3D%3D?line=55'>56</a>     if (i==10000):
#      <a href='vscode-notebook-cell:/c%3A/Users/jdss0/Documents/workspace/ising-models/notebooks/jonas/2d_langevin_v4.ipynb#X11sZmlsZQ%3D%3D?line=56'>57</a>         master_list.append(u)
#
# KeyboardInterrupt:

# %%
for T in np.linspace(0.01, 15, num=30):
  T = float(T)
  print(f"---------------- Temperature: {T} --------------------- ")
  for realization in tqdm(range(N_real), desc="Processing", ncols=100, ascii=True):
    u = torch.randn(Ng * Ng, 1, device=device)  # Initial data
    integrate(L, u, T)    # simulate
    # if realization % 10 ==0:
      # print(f'Realization: {realization}')

  mean_config = avg_realizations(master_list, Ng)
  VEV = avg_final(mean_config, Ng)
  list_vev.append(VEV)
# Out:
# ---------------- Temperature: 0.01 ---------------------
# Processing: 100%|###################################################| 50/50 [06:40<00:00,  8.00s/it]
# Processing: 100%|##############################################| 4096/4096 [00:05<00:00, 696.60it/s]
# ---------------- Temperature: 0.526896551724138 ---------------------
# Processing: 100%|###################################################| 50/50 [06:09<00:00,  7.39s/it]
# Processing: 100%|##############################################| 4096/4096 [00:07<00:00, 564.97it/s]
# ---------------- Temperature: 1.043793103448276 ---------------------
# Processing: 100%|###################################################| 50/50 [06:29<00:00,  7.80s/it]
# Processing: 100%|##############################################| 4096/4096 [00:09<00:00, 444.11it/s]
# ---------------- Temperature: 1.5606896551724139 ---------------------
# Processing: 100%|###################################################| 50/50 [06:28<00:00,  7.77s/it]
# Processing: 100%|##############################################| 4096/4096 [00:10<00:00, 400.51it/s]
# ---------------- Temperature: 2.0775862068965516 ---------------------
# Processing: 100%|###################################################| 50/50 [06:41<00:00,  8.03s/it]
# Processing: 100%|##############################################| 4096/4096 [00:10<00:00, 396.44it/s]
# ---------------- Temperature: 2.5944827586206896 ---------------------
# Processing:  72%|####################################7              | 36/50 [04:41<01:49,  7.82s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\jdss0\Documents\workspace\ising-models\notebooks\jonas\2d_langevin_v4.ipynb Cell 10 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/jdss0/Documents/workspace/ising-models/notebooks/jonas/2d_langevin_v4.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a> for realization in tqdm(range(N_real), desc="Processing", ncols=100, ascii=True):
#       <a href='vscode-notebook-cell:/c%3A/Users/jdss0/Documents/workspace/ising-models/notebooks/jonas/2d_langevin_v4.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a>   u = torch.randn(Ng * Ng, 1, device=device)  # Initial data
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jdss0/Documents/workspace/ising-models/notebooks/jonas/2d_langevin_v4.ipynb#X12sZmlsZQ%3D%3D?line=5'>6</a>   integrate(L, u, T)    # simulate
#       <a href='vscode-notebook-cell:/c%3A/Users/jdss0/Documents/workspace/ising-models/notebooks/jonas/2d_langevin_v4.ipynb#X12sZmlsZQ%3D%3D?line=6'>7</a>   # if realization % 10 ==0:
#       <a href='vscode-notebook-cell:/c%3A/Users/jdss0/Documents/workspace/ising-models/notebooks/jonas/2d_langevin_v4.ipynb#X12sZmlsZQ%3D%3D?line=7'>8</a>     # print(f'Realization: {realization}')
#      <a href='vscode-notebook-cell:/c%3A/Users/jdss0/Documents/workspace/ising-models/notebooks/jonas/2d_langevin_v4.ipynb#X12sZmlsZQ%3D%3D?line=9'>10</a> mean_config = avg_realizations(master_list, Ng)
#
# c:\Users\jdss0\Documents\workspace\ising-models\notebooks\jonas\2d_langevin_v4.ipynb Cell 10 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/jdss0/Documents/workspace/ising-models/notebooks/jonas/2d_langevin_v4.ipynb#X12sZmlsZQ%3D%3D?line=52'>53</a> for i in range(Tf.item()):
#      <a href='vscode-notebook-cell:/c%3A/Users/jdss0/Documents/workspace/ising-models/notebooks/jonas/2d_langevin_v4.ipynb#X12sZmlsZQ%3D%3D?line=53'>54</a>     noise = torch.normal(mean=0.0, std=1.0, size=(Ng * Ng, 1), device='cpu')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/jdss0/Documents/workspace/ising-models/notebooks/jonas/2d_langevin_v4.ipynb#X12sZmlsZQ%3D%3D?line=54'>55</a>     u = u - dt * (a * u + b * u * u * u - c - k * torch.mm(L, u)) + torch.sqrt(2 * T * dt) * noise  # Euler's method
#      <a href='vscode-notebook-cell:/c%3A/Users/jdss0/Documents/workspace/ising-models/notebooks/jonas/2d_langevin_v4.ipynb#X12sZmlsZQ%3D%3D?line=55'>56</a>     if (i==10000):
#      <a href='vscode-notebook-cell:/c%3A/Users/jdss0/Documents/workspace/ising-models/notebooks/jonas/2d_langevin_v4.ipynb#X12sZmlsZQ%3D%3D?line=56'>57</a>         master_list.append(u)
#
# KeyboardInterrupt:

# %%
list_vev
# Out:
# [tensor(1.0021),
#  tensor(0.8154),
#  tensor(0.8154),
#  tensor(0.7599),
#  tensor(0.6892),
#  tensor(0.6261)]

# %%
list_T = np.linspace(0.01, 15, num=30)[:6]
list_T = list(list_T)
list_T
# Out:
# [0.01,
#  0.526896551724138,
#  1.043793103448276,
#  1.5606896551724139,
#  2.0775862068965516,
#  2.5944827586206896]

# %%
plt.plot(list_T, list_vev)
plt.show()

# %%
list_temperature = np.linspace(0.01, 15, num=30)
# Out:
# array([1.00000000e-02, 5.26896552e-01, 1.04379310e+00, 1.56068966e+00,
#        2.07758621e+00, 2.59448276e+00, 3.11137931e+00, 3.62827586e+00,
#        4.14517241e+00, 4.66206897e+00, 5.17896552e+00, 5.69586207e+00,
#        6.21275862e+00, 6.72965517e+00, 7.24655172e+00, 7.76344828e+00,
#        8.28034483e+00, 8.79724138e+00, 9.31413793e+00, 9.83103448e+00,
#        1.03479310e+01, 1.08648276e+01, 1.13817241e+01, 1.18986207e+01,
#        1.24155172e+01, 1.29324138e+01, 1.34493103e+01, 1.39662069e+01,
#        1.44831034e+01, 1.50000000e+01])
